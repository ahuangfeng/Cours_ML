# %% [markdown]
# # K Means Clustering with Python
#
# ## Method Used
#
# K Means Clustering is an unsupervised learning algorithm that tries to cluster data based on their similarity. Unsupervised learning means that there is no outcome to be predicted, and the algorithm just tries to find patterns in the data. In k means clustering, we have the specify the number of clusters we want the data to be grouped into. The algorithm randomly assigns each observation to a cluster, and finds the centroid of each cluster. Then, the algorithm iterates through two steps:
# Reassign data points to the cluster whose centroid is closest. Calculate new centroid of each cluster. These two steps are repeated till the within cluster variation cannot be reduced any further. The within cluster variation is calculated as the sum of the euclidean distance between the data points and their respective cluster centroids.

# %% [markdown]
# ## Import Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Create some Data

# %%
from sklearn.datasets import make_blobs

# %%
# Create Data
# make_blobs devuelve un array de 
data = make_blobs(n_samples=200, n_features=2, 
                           centers=4, cluster_std=1.8,random_state=101)

# %%
data
# Out:
# (array([[ -1.57458666,   5.39948826],
#         [  2.67397222,   6.07502776],
#         [  0.08525926,   2.11630185],
#         [ -2.01452794,   7.0759891 ],
#         [ -1.70963014,   6.58521576],
#         [-10.47520484,  -4.39331776],
#         [ -0.37610937,   3.26427943],
#         [ -1.71798771,   1.4140114 ],
#         [  0.66479669,   0.09423047],
#         [  2.999736  ,   6.23226473],
#         [  0.31468394,   4.31248134],
#         [  0.87277036,   4.462053  ],
#         [  0.94634309,   1.76664731],
#         [ -1.44975752,   7.23011268],
#         [-13.12512873,  -6.86952988],
#         [  6.13879231,   7.14086644],
#         [ -7.9866826 ,  -9.57113308],
#         [ -4.36545465,   9.69842111],
#         [  1.54753576,   1.4603416 ],
#         [ -3.22271663,  -0.14704133],
#         [ -7.80542892,  -7.53780336],
#         [ -7.83025988,  -9.88023643],
#         [-10.96926329,  -3.68449891],
#         [ -5.10629357,   8.99421177],
#         [ -2.69293803,   2.01450332],
#         [ -4.4585243 ,   9.88762908],
#         [  2.26791554,   6.33718003],
#         [ -3.21600348,   7.90987253],
#         [ -7.92867733,  -6.82234417],
#         [  3.67678506,   4.09830219],
#         [  2.36863794,   2.36408786],
#         [  2.05859724,  -2.44083039],
#         [  0.2711301 ,   2.58303824],
#         [ -1.03161306,   0.78979843],
#         [  3.37811299,   5.59211341],
#         [  7.04448053,   7.58198786],
#         [ -3.01188634,   9.58314986],
#         [  1.52734733,   0.44452941],
#         [  0.91809309,   2.62742507],
#         [  3.45126043,   6.83188911],
#         [-10.8091896 ,  -4.83742837],
#         [  5.06587559,   9.84255639],
#         [  6.49756604,   8.91470466],
#         [ -5.51242378,   8.3466393 ],
#         [ -8.83495735,  -8.48305488],
#         [ -3.27429696,   5.60262118],
#         [ -9.11009911,  -7.6978166 ],
#         [ -0.6954739 ,   3.94656058],
#         [ -4.4918711 ,  10.6581975 ],
#         [ -1.19856602,   2.50408937],
#         [  1.55508084,   6.41652092],
#         [  2.08426798,   0.71452208],
#         [  5.26010157,   5.36980407],
#         [  4.45688093,   8.96982209],
#         [ -6.3554271 ,   9.21476994],
#         [ -9.15392597,  -6.26781804],
#         [ -9.21605454,  -5.37128062],
#         [-10.13447561,  -3.43130837],
#         [ -3.29675444,   7.74891051],
#         [  6.23847955,   6.78768471],
#         [-11.40636291, -10.00398275],
#         [ -1.45220979,   6.86226284],
#         [ -2.9402567 ,   8.13257541],
#         [  3.15029055,   5.16221756],
#         [ -7.39648298,  -4.95353352],
#         [ -7.08762039,  10.4902355 ],
#         [ -4.84001768,   7.26841681],
#         [  0.75456469,   1.77475658],
#         [  0.82703245,   2.95403181],
#         [ -4.81431623,   6.02771768],
#         [-11.65462114,  -8.0067372 ],
#         [ -3.80007258,   7.64758379],
#         [ -1.09464587,   4.46210405],
#         [ -7.26737622,  -8.04640057],
#         [ -9.01635879,  -5.45598249],
#         [  3.02538895,  10.19769305],
#         [  5.5725203 ,   8.01349423],
#         [  0.92923273,   5.19994002],
#         [  6.70975924,   9.34220312],
#         [ -7.10810159,  -9.23054173],
#         [ -4.54389181,  10.05883396],
#         [  1.48322247,  -0.21582809],
#         [  1.87066634,   4.43990483],
#         [-11.98822453,  -5.99057962],
#         [  1.64021527,  -0.14021255],
#         [ -1.42053406,  -1.32684744],
#         [ -0.56681469,   0.05602628],
#         [ -0.7039768 ,   5.05320236],
#         [ -9.80094161,  -2.08038454],
#         [ -8.95134327,  -5.82692258],
#         [ -7.61733203,  -5.9759563 ],
#         [ -9.65620091,  -8.2716255 ],
#         [-10.42209228,  -4.87388592],
#         [ -9.96769981,  -6.51711222],
#         [ -1.12040017,   1.86973821],
#         [  4.68502626,   7.93486957],
#         [-12.21992346,  -5.78611162],
#         [ -3.30473029,   2.74557144],
#         [ -3.21488622,   9.91414179],
#         [  2.17474403,   1.13147551],
#         [  0.66762411,   0.04738204],
#         [ -8.69685986,  -5.11544994],
#         [  2.98370943,   3.4748905 ],
#         [ -1.28438223,   5.19584446],
#         [ -0.71333412,   6.60863268],
#         [ -0.57304723,   7.35494797],
#         [ -2.03339914,   9.83745796],
#         [ -8.24066291,  -7.16882432],
#         [  1.27983684,   0.35315078],
#         [  1.55414928,   3.27657687],
#         [  1.4964385 ,   2.05944468],
#         [  0.55045544,   6.44229291],
#         [  1.48423611,   4.97599593],
#         [ -6.34800692,   8.823726  ],
#         [ -9.66794652,  -8.972732  ],
#         [  1.03620192,   0.2784398 ],
#         [-11.37652837,  -6.57020581],
#         [ -1.33860111,   4.76650719],
#         [  0.05638263,   7.85270963],
#         [ -0.88924883,   6.6204687 ],
#         [ -5.77733594,  -8.45301197],
#         [ -9.51273313,  -6.54720909],
#         [  0.01467078,   2.81760322],
#         [ -1.94652566,   6.79218883],
#         [ -1.93732804,   2.90923064],
#         [ -5.9505711 ,   8.48295825],
#         [ -3.38433735,   8.16149473],
#         [  5.74344504,   5.02513836],
#         [  1.3807331 ,   8.47974121],
#         [ -5.46390421,   2.86112175],
#         [ -2.16643499,   7.85730094],
#         [  4.20382576,   5.68157442],
#         [  2.16059205,   6.27795881],
#         [ -0.34976106,   1.82795716],
#         [-10.27427678,  -5.02139221],
#         [ -2.81474905,   7.16450283],
#         [-11.28375435,  -9.31430684],
#         [  5.39775612,   8.02113545],
#         [ -0.99611179,   4.92390123],
#         [ -6.33559724,   5.85002979],
#         [-10.23308648,  -5.3349941 ],
#         [-10.87563318,  -7.02582976],
#         [ -8.33457235,  -6.0539155 ],
#         [ -1.61687608,   3.0376677 ],
#         [  5.80488792,   8.92965314],
#         [ -6.57605316,  -4.89618276],
#         [  1.38175422,   6.6619599 ],
#         [  5.96083817,   4.79091205],
#         [ -9.49249242,  -5.33043171],
#         [  1.33375749,   3.25801024],
#         [  3.66469466,   6.73459089],
#         [ -0.57341769,   6.11915977],
#         [  0.67140233,   4.97511492]]),
#  array([3, 2, 0, 3, 3, 1, 0, 0, 0, 2, 2, 0, 0, 3, 1, 2, 1, 3, 0, 0, 1, 1,
#         1, 3, 0, 3, 2, 3, 1, 2, 0, 0, 0, 0, 2, 2, 3, 0, 0, 2, 1, 2, 2, 3,
#         1, 3, 1, 0, 3, 0, 2, 0, 2, 2, 3, 1, 1, 1, 3, 2, 1, 3, 3, 2, 1, 3,
#         3, 0, 2, 3, 1, 3, 3, 1, 1, 2, 2, 2, 2, 1, 3, 0, 2, 1, 0, 0, 0, 3,
#         1, 1, 1, 1, 1, 1, 0, 2, 1, 0, 3, 0, 0, 1, 2, 3, 3, 3, 3, 1, 0, 0,
#         0, 2, 2, 3, 1, 0, 1, 0, 3, 2, 1, 1, 0, 3, 3, 3, 3, 2, 2, 3, 3, 2,
#         3, 3, 1, 0, 0, 0, 3, 2, 3, 2, 2, 2, 1, 3, 2, 2, 3, 2, 3, 0, 1, 2,
#         2, 1, 3, 1, 2, 3, 1, 2, 1, 0, 2, 0, 0, 0, 3, 0, 2, 1, 1, 2, 0, 0,
#         3, 1, 2, 3, 2, 1, 0, 0, 0, 2, 3, 1, 0, 2, 1, 2, 3, 0, 2, 0, 2, 3,
#         2, 0, 2, 2, 0, 2, 3, 3, 3, 0, 1, 3, 1, 2, 0, 0, 3, 1, 0, 1, 2, 0,
#         1, 2, 2, 3, 3, 3, 0, 2, 3, 3, 0, 0, 0, 1, 0, 2, 3, 1, 1, 2, 3, 0,
#         1, 3, 1, 3, 0, 1, 2, 0, 2, 1, 1, 0, 0, 0, 0, 1, 3, 1, 0, 3, 1, 1,
#         1, 3, 1, 1, 1, 2, 2, 0, 3, 2, 2, 3, 1, 3, 2, 2, 0, 1, 3, 1, 2, 3,
#         3, 1, 1, 1, 0, 2, 1, 2, 2, 1, 0, 2, 3, 0]))

# %% [markdown]
# ## Visualize Data

# %%
sns.set_style('darkgrid')
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow',s=5)

# %% [markdown]
# ## Creating the Clusters

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-9.51083714, -6.50944858],
#        [-3.67618674,  7.59124984],
#        [ 4.18620177,  6.80055146],
#        [ 0.22590361,  2.10954545]])

# %%
kmeans.labels_
# Out:
# array([1, 2, 3, 1, 1, 0, 3, 3, 3, 2, 3, 3, 3, 1, 0, 2, 0, 1, 3, 3, 0, 0,
#        0, 1, 3, 1, 2, 1, 0, 2, 3, 3, 3, 3, 2, 2, 1, 3, 3, 2, 0, 2, 2, 1,
#        0, 1, 0, 3, 1, 3, 2, 3, 2, 2, 1, 0, 0, 0, 1, 2, 0, 1, 1, 2, 0, 1,
#        1, 3, 3, 1, 0, 1, 3, 0, 0, 2, 2, 3, 2, 0, 1, 3, 3, 0, 3, 3, 3, 3,
#        0, 0, 0, 0, 0, 0, 3, 2, 0, 3, 1, 3, 3, 0, 3, 1, 1, 1, 1, 0, 3, 3,
#        3, 2, 3, 1, 0, 3, 0, 3, 1, 1, 0, 0, 3, 1, 3, 1, 1, 2, 2, 1, 1, 2,
#        1, 1, 0, 3, 3, 3, 1, 2, 1, 2, 2, 2, 0, 1, 2, 2, 1, 2, 1, 3, 0, 2,
#        2, 0, 1, 0, 2, 1, 0, 2, 0, 3, 2, 3, 3, 3, 1, 1, 2, 0, 0, 2, 3, 3,
#        1, 0, 2, 1, 2, 0, 3, 3, 3, 2, 1, 0, 3, 2, 0, 2, 1, 3, 2, 3, 2, 1,
#        2, 3, 2, 2, 3, 2, 1, 1, 1, 3, 0, 1, 0, 3, 3, 3, 1, 0, 3, 0, 2, 3,
#        0, 2, 2, 1, 1, 1, 3, 2, 1, 1, 3, 3, 3, 0, 3, 2, 1, 0, 0, 2, 1, 3,
#        0, 1, 0, 1, 3, 0, 2, 3, 2, 0, 0, 2, 3, 3, 3, 0, 1, 0, 3, 1, 0, 0,
#        0, 1, 0, 0, 0, 2, 2, 3, 1, 2, 2, 1, 0, 1, 2, 2, 3, 0, 1, 0, 2, 3,
#        1, 0, 0, 0, 3, 2, 0, 2, 2, 0, 3, 2, 1, 3], dtype=int32)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(12,8))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow',s=10)
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow',s=10)

# %% [markdown]
# You should note, the colors are meaningless in reference between the two plots.

# %% [markdown]
# ## Seeking the elbow
#
# The goal for this section is to design a method for selecting the optimal value of K.

# %%
from numpy.linalg import norm
import numpy as np

# %%
### Elbow method:

# %%
sse = []

for i in range(1,20):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data[0])
    sse.append(sum( 
        [norm(
            data[0][j]-
            kmeans.cluster_centers_[kmeans.labels_[j]])**2 
         for j in range(len(data[0]))
        ]))
    
plt.figure(figsize=(15,6))
plt.plot(range(1,len(sse)+1), sse, color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=5)
plt.xticks(list(range(1,20)))
plt.title('SSE vs K Value')
plt.xlabel('K')
plt.ylabel('Sum of Squared Errors')
# Out:
# Text(0,0.5,'Sum of Squared Errors')

# %%
# el valor apropiado es el que está en el codo: en este caso 4

# %% [markdown]
# # Great Job!
